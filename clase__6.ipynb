# %% [markdown]
# ## Dia 6
# ## Programacion orientada a objetos
# # Temario
# - 1.- ¿Que es POO?
# - 2.- Entidades: Clases y Objetos
# - 3.- self, _init_ y el ciclo de vida de un objeto
# - 4.- Atributos: De instancia vs de clase
# - 5.- Metodo: Instancia, clase
# - 6.- Encapsulamiento y propiedades
# - 7.- Herencia y Abstraccion
# - 8.- Polimorfismo
# - 9.- Composicion vs Herencia

# %% [markdown]
# ## 1.- ¿Que es POO y por que usarla?
# 1. Clases (Los molde)
#
# Una clase es como el molde o plano para crear algo
#
# 2. Objetos (Las Creaciones)
#
# Un objeto es una instancia real tangible creada a partir de una clase

# %% [markdown]
# ## 2.- Entidades: Clases y Objeto

# %%
class Perro: # creaste tu clase
  def ladrar(self): # Metodo (acciones)
    print("Guau!")

mi_perro = Perro() # Cracion de tu objeto
mi_perro.ladrar() # Acciones de tu objeto
# Out:
# Guau!

# %% [markdown]
# ## 3.- self, __ init __ y el ciclo de vida de un objeto

# %%
class Perro:
# self es la referencia a la instancia actual, __ init __
  def __init__(self, nombre, edad): # constructor
    self.nombre = nombre
    self.edad = edad
  def presentarse(self):
    print(f"Soy {self.nombre} y tengo {self.edad} años")

naylah = Perro("Naylah", 5)
naylah.presentarse()
# 1.- __init__ no retorna la instancia: Pyhon lo llama al crear wl objeto
# 2.- Evita usar valores mutables como parametros por defecto
# Out:
# Soy Naylah y tengo 5 años

# %% [markdown]
# ## 4.- Atributos: de instancia vs de clase

# %%
class Perro:
  patas = 4
  especie = "Caninis familliae" # Atributos de clase
  def __init__(self, nombre):
    self.nombre = nombre # Atributos de instancia

p1 = Perro("Firulais")
p2 = Perro("Bobby")

print(p1.especie)
print(p2.especie)
print("-----------------------")
p2.especie = "Gato" # Cambio de atributo de la clase ESPECIALMENTE para p2
print(p1.especie)
print(p2.especie)
# Out:
# Caninis familliae
# Caninis familliae
# -----------------------
# Caninis familliae
# Gato

# %%
print(p1.__dict__)
print(p2.__dict__)
# Out:
# {'nombre': 'Firulais'}
# {'nombre': 'Bobby', 'especie': 'Gato'}

# %% [markdown]
# ## 5.- Metodo de instancia, clase
#
# Un metodo de instancia es una funcion definida dentro de una clase que:
# - Opera sobre un objeto concreto (una instancia)
# - Puede acceder y modificar los atributos de ese objeto
# - Recibe como primer parametro a self

# %%
# Ya lo hemos usado
class tuClase:
  def metodo(self):
    pass

# Metodo: Metodo de instancia
# self: Referencia al objeto que llama al metodo

# %%
# CALCULADORA:
class Calculadora:
  def __init__(self, num1, num2):
    self.num1 = num1
    self.num2 = num2
  def sumar(self):
    print(self.num1 + self.num2)
  def restar(self):
    print(self.num1 - self.num2)
  def multiplicar(self):
    print(self.num1 * self.num2)
  def dividir(self):
    if self.num2 == 0:
      print("No se puede dividir entre 0")
    else:
      print(self.num1 / self.num2)

calculadora = Calculadora(7, 0)
calculadora.dividir()
calculadora.sumar()
calculadora.multiplicar()
# Out:
# No se puede dividir entre 0
# 7
# 0

# %%
from enum import nonmember
# EJERCICIO, CREAR UNA CLASE DE ANIMAL, donde tenga una instancia (constructor) de por lo menos 3 variables con 1 metodo y crea 4 objetos
class animal: # 1.- Crear clase
  def __init__(self, nombre, especie, patas, comida_favorita, sonido): # 2.- instancia
    self.nombre = nombre # 3.- Variables
    self.especie = especie
    self.patas = patas
    self.comida_favorita = comida_favorita
    self.sonido = sonido

  def hacer_sonido(self): # 4.- Metodo
    print(self.sonido)

gato  = animal("Rayitas", "Gato", 4, "Carne de res", "Miau") # 4 objetos
perro = animal("Mechas", "Perro", 4, "Pollito Asado", "woof")
pajaro = animal("Paco", "Perico", 2, "Semillas", "pipipi")
vaca = animal("Manchas", "Vaca", 4, "Pasto", "Muuu")

vaca.hacer_sonido()
gato.nombre = "Juan"
gato.nombre
# Out:
# Muuu
# 'Juan'

# %% [markdown]
# ## 6.- Encapsulamiento y propiedades

# %%
class Cuenta:
  def __init__(self, saldo):
    self.__saldo = saldo # Atributo privado
# Sirve para proteger los datos internos de un objeto y controlar como se leen y modofican
cuenta = Cuenta(1000)
cuenta.Cuenta = 2000 # Si puedes editarlo
#print(cuenta.__saldo) # No puedes acceder directamente

# %%
# Getters y Setters
class Cuenta:
  def __init__(self, saldo):
    self.__saldo = saldo
  @property
  def saldo(self): # Getter
  # PErmite leer el valor de __saldo usando c.saldo
    return self.__saldo
  @saldo.setter # Setter
  def saldo(self, valor):
    # se ejecuta cuando hacemos c.saldo = valor
    self.__saldo = valor

c = Cuenta(300)
print(c.saldo)
c.saldo = 4000
print(c.saldo)
# Out:
# 300
# 4000

# %% [markdown]
# ## 7.- Herencia y Abstraccion

# %%
# Herencia
class Vehiculo: # Clase BAse (padre)
  def __init__(self, marca, modelo):
    self.marca = marca
    self.modelo = modelo
  def descripcion(self):
    return f"{self.marca}:{self.modelo}"
  def mover(self):
    return f"El vehiculo se esta moviendo..."

#-------------------------------------------------------------------------
class Coche(Vehiculo): # Clase Hija (subclase)
  def mover(self):
    return "El coche esta conduciendo"
#-------------------------------------------------------------------------
class Moto(Vehiculo):
  def mover(self):
    return "La moto avanza sobre dos ruedas"

coche2 = Vehiculo("BYD", "Dolphin")
coche = Coche("Toyota", "Corolla")
moto = Moto("Yamaha", "R6")
print(coche.mover())
print(coche2.mover())
print(moto.mover())
#print(coche2.descripcion())
#print(coche2.mover())
#print(coche.descripcion())
# aunque no volvimos a declarar el metodo dentro de descripcion, podemos seguir usandolo ya que lo heredo del padre print(coche.mover())print(moto.descripcion())print(moto.mover())
# Out:
# El coche esta conduciendo
# El vehiculo se esta moviendo...
# La moto avanza sobre dos ruedas

# %%
class Persona:
  def __init__(self, nombre, edad):
    self.nombre = nombre
    self.edad = edad
  def presentarse(self):
    print(f"Hola, soy {self.nombre} y tengo {self.edad} años")

class Estudiante(Persona):
  def __init__(self, nombre, edad, carrera):
    super().__init__(nombre, edad)
    self.carrera = carrera
  def presentarse(self):
    super().presentarse()
    print(f"Estudio la carrera de {self.carrera}")
# reutiliza el constructor de la clase padre (lo cual evita duplicar el codigo)
# Ejecuta el comportamiento base y luego lo extiende
est = Estudiante("Ana",21, "programacion")
est.presentarse()
# Out:
# Hola, soy Ana y tengo 21 años
# Estudio la carrera de programacion

# %%
# Abstraccion
class Animal:
  def hablar(self):
    raise NotImplementedError("La subclase debe implementar el metodo hablar")
class Gato(Animal):
  def hablar(self):
    print("Miau")

# %% [markdown]
# ## Polimorfismo
# (Justo ya lo implementamos). El polimorfismo significa que diferentes objetos pueden responder al mismo mensaje (metodo) de forma distinta, siempre y cuando compartan una interfaz común

# %% [markdown]
# ## Composicion  HAS-A
# ¿Por qué se llama composición?
# Porque estas componiendo (armando) un objeto grande usando otros objetos. es un principio de POO donde:
# - Una clase NO hereda de otra, si no que contiene un objeto de esa otra clase

# %%
class Banco:
  def __init__(self,dinero):
    self.dinero = dinero
  def ver_total(self):
    print(f"Total en la cuenta: ${self.dinero}")
class Persona:
  def __init__(self, cuenta:Banco): # Indica que este parametro deberia ser una instancia de la clase Banco
    self.cuenta = cuenta # Persona TIENE un banco, no hereda de el

# %% [markdown]
# ## 9.- Composicion vs HErencia
# Esot se va a responder con teoria:
#
# No significa que alguna sea mejor que otra simplemente que aveces una te puede convenir mas que otra:
#
# Herencia: Un gato ES un animal (no "Un gato TIENE un animal")
#
# Composicion: Una persona TIENE una cuenta (no "Una persona es un banco")

# %%
''' Ejercicio aplicando todo:
Queremos modelar un pequeño sistema para vehículos.
Habrá distintos tipos: Coche, Moto, Bicicleta.
Todos son “vehículos” (clase Vehiculo), por lo tanto comparten características básicas,
pero cada uno se mueve distinto. Además, usamos una clase Motor con Composición.
Opcional: Polimorfismo.
'''
class Vehiculo:
    def __init__(self, marca):
        self.marca = marca

    def mover(self):
        raise NotImplementedError("Este método DEBE ser implementado.")


class Motor:
    def __init__(self, caballos):
        self.caballos = caballos

    def potencia(self):
        return f"{self.caballos} HP"


class Coche(Vehiculo):
    def __init__(self, marca, caballos):
        super().__init__(marca)
        self.motor = Motor(caballos)   # COMPOSICIÓN

    def mover(self):  # POLIMORFISMO
        return f"El coche {self.marca} avanza con motor de {self.motor.potencia()}"


class Moto(Vehiculo):
    def __init__(self, marca, caballos):
        super().__init__(marca)
        self.motor = Motor(caballos)   # COMPOSICIÓN

    def mover(self):  # POLIMORFISMO
        return f"La moto {self.marca} acelera con motor de {self.motor.potencia()}"


class Bicicleta(Vehiculo):
    def mover(self):  # POLIMORFISMO
        return f"La bicicleta {self.marca} avanza con pedaleo humano"


def probar_vehiculos(lista):
    # --- llamada al polimorfismo ---
    for v in lista:
        print(v.mover())


# Lo usaremos en esta ocasión en una lista.
# Sí se puede hacer listas de clases.
vehiculos = [
    Coche("Toyota", 150),
    Moto("Yamaha", 90),
    Bicicleta("Trek")
]

probar_vehiculos(vehiculos)
